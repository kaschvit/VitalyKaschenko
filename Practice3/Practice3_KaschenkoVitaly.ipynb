# %% [markdown]
# # Практическая работа №3

# %% [markdown]
# ## Тема "Визуализация данных"

# %% [markdown]
# ### Выполнил студент: Кащенко Виталий

# %% [markdown]
# #### Вариант: 9

# %% [markdown]
# ##### Задание 1. Загрузить и данные из файла Dataset_Variants.xlsx, где номер листа ваш вариант

# %%
import pandas as pd
myDF = pd.read_excel('dataset_variants.xlsx', sheet_name='9')

# %% [markdown]
# ##### Задание 2. Отобразить данные вашего варианта

# %%
myDF.head(10)
# Out:
#     X          Y
# 0   1  64.522925
# 1   2   2.673761
# 2   3  32.950612
# 3   4  13.152391
# 4   5  37.968408
# 5   6  80.374622
# 6   7  51.687113
# 7   8  19.460703
# 8   9  43.463092
# 9  10  33.948300

# %% [markdown]
# ##### Задание 3. Визуализировать данные в стиле Столбчатые диаграммы (подписать оси)

# %%
import matplotlib.pyplot as plt
plt.bar(myDF.X, myDF.Y)
plt.xlabel('Ось X', loc = ('left'))
plt.ylabel('Ось Y', rotation=0, loc = ('top'))
# Out:
# Text(0, 1, 'Ось Y')

# %% [markdown]
# ##### Задание 4. Визуализировать данные в стиле Точечный график (подписать оси)

# %%
plt.scatter(myDF.X, myDF.Y)
plt.xlabel('Ось X', loc = ('left'))
plt.ylabel('Ось Y', rotation=0, loc = ('top'))
# Out:
# Text(0, 1, 'Ось Y')

# %% [markdown]
# ##### Задание 5. Отрицательные значение по Y заменить значением по модулю

# %%
import math
for i in range(myDF.shape[0]):
    if myDF.iat[i,1] < 0:
        myDF.iat[i,1] = math.fabs(myDF.iat[i,1])

# %% [markdown]
# ##### Задание 6. Отобразить изменённые данные вашего варианта

# %%
myDF.head()
# Out:
#    X          Y
# 0  1  64.522925
# 1  2   2.673761
# 2  3  32.950612
# 3  4  13.152391
# 4  5  37.968408

# %% [markdown]
# ##### Задание 7. Визуализировать изменённые данные вашего варианта в стиле Столбчатые диаграммы (подписать оси, столбцы зеленого цвета)

# %%
plt.bar(myDF.X, myDF.Y, color = "green")
plt.xlabel('Ось X', loc = ('left'))
plt.ylabel('Ось Y', rotation=0, loc = ('top'))
# Out:
# Text(0, 1, 'Ось Y')

# %% [markdown]
# ##### Задание 8. Визуализировать изменённые данные вашего варианта в стиле Точечный график (подписать оси, столбцы зеленого цвета)

# %%
plt.scatter(myDF.X, myDF.Y, color = "green")
plt.xlabel('Ось X', loc = ('left'))
plt.ylabel('Ось Y', rotation=0, loc = ('top'))
# Out:
# Text(0, 1, 'Ось Y')

# %% [markdown]
# ##### Задание 9. Визуализировать изменённые данные вашего варианта в стиле Линейный график (подписать оси, цвет, стиль линии изменить на ваше усмотрение)

# %%
plt.figure(facecolor = "pink")
plt.plot(myDF.X, myDF.Y, color = "pink", linestyle='-.')
plt.grid(True)
plt.xticks(range(0, myDF.X.max(), 5))
plt.yticks(range(0, int(myDF.Y.max()), 10))
plt.xlabel('Ось X', loc = ('left'))
plt.ylabel('Ось Y', rotation=0, loc = ('top'))
# Out:
# Text(0, 1, 'Ось Y')

# %% [markdown]
# ##### Задание 10. Визуализировать изменённые данные вашего варианта в стиле Линейный график с маркером (подписать оси, цвет, стиль линии и тип маркера изменить на ваше усмотрение)

# %%
plt.figure(facecolor = "pink")
plt.plot(myDF.X, myDF.Y, color = "pink", linestyle='-.', marker ='h')
plt.grid(True)
plt.xticks(range(0, myDF.X.max(), 5))
plt.yticks(range(0, int(myDF.Y.max()), 10))
plt.xlabel('Ось X', loc = ('left'))
plt.ylabel('Ось Y', rotation=0, loc = ('top'))
# Out:
# Text(0, 1, 'Ось Y')

# %% [markdown]
# ##### Задание 11. Визуализировать изменённые данные вашего варианта в стиле Цветовое распределение

# %%
plt.pcolor(myDF)

# %% [markdown]
# ##### Задание 12. Загрузить и данные из файла Dataset_Variants.xlsx c номером листа 10000, где номер столбца Y ваш вариант

# %%
myDF = pd.read_excel('dataset_variants.xlsx', sheet_name = '10000', usecols = ['X','Y9'])

# %% [markdown]
# ##### Задание 13. Отобразить данные вашего варианта

# %%
myDF.head()
# Out:
#    X           Y9
# 0  1  1002.086040
# 1  2   994.684686
# 2  3  1045.003162
# 3  4  1028.288923
# 4  5   978.742295

# %% [markdown]
# ##### Задание 14. Визуализировать данные в стиле Столбчатые диаграммы (подписать оси)

# %%
plt.bar(myDF.X, myDF.Y9)
plt.xlabel('Ось X', loc = ('left'))
plt.ylabel('Ось Y', rotation=0, loc = ('top'))
# Out:
# Text(0, 1, 'Ось Y')

# %% [markdown]
# ##### Задание 15. Визуализировать данные в стиле Точечный график (подписать оси)

# %%
plt.scatter(myDF.X, myDF.Y9)
plt.xlabel('Ось X', loc = ('left'))
plt.ylabel('Ось Y', rotation=0, loc = ('top'))
# Out:
# Text(0, 1, 'Ось Y')

# %% [markdown]
# ##### Задание 16. Визуализировать данные вашего варианта в стиле Столбчатые диаграммы (подписать оси, столбцы зеленого цвета)

# %%
plt.bar(myDF.X, myDF.Y9, color = "green")
plt.xlabel('Ось X', loc = ('left'))
plt.ylabel('Ось Y', rotation=0, loc = ('top'))
# Out:
# Text(0, 1, 'Ось Y')

# %% [markdown]
# ##### Задание 17. Визуализировать данные вашего варианта в стиле Точечный график (подписать оси, столбцы красного цвета)

# %%
plt.scatter(myDF.X, myDF.Y9, color = "red")
plt.xlabel('Ось X', loc = ('left'))
plt.ylabel('Ось Y', rotation=0, loc = ('top'))
# Out:
# Text(0, 1, 'Ось Y')

# %% [markdown]
# ##### Задание 18. Визуализировать данные вашего варианта в стиле Линейный график (подписать оси, цвет, стиль линии изменить на ваше усмотрение)

# %%
plt.figure(facecolor = "pink")
plt.plot(myDF.X, myDF.Y9, color = "pink", linestyle='-.')
plt.grid(True)
plt.xlabel('Ось X', loc = ('left'))
plt.ylabel('Ось Y', rotation=0, loc = ('top'))
# Out:
# Text(0, 1, 'Ось Y')

# %% [markdown]
# ##### Задание 19. Визуализировать данные вашего варианта в стиле Цветовое распределение

# %%
plt.pcolor(myDF)

# %% [markdown]
# ##### Задание 20. Загрузить и данные из вашего скаченного DataSet

# %%
url = "https://raw.githubusercontent.com/kaschvit/VitalyKaschenko/main/Practice2/crypto-markets.csv"
myDF = pd.read_csv(url, sep = ';')

# %% [markdown]
# ##### Задание 21. Отобразить данные вашего скаченного DataSet

# %%
myDF.head()
# Out:
#       slug symbol     name        date  ranknow   open    high     low  \
# 0  bitcoin    BTC  Bitcoin  01.05.2013        1  139.0  139.89  107.72
# 1  bitcoin    BTC  Bitcoin  29.04.2013        1    NaN  147.49     NaN
# 2  bitcoin    BTC  Bitcoin  30.04.2013        1  144.0  146.93  134.05
# 3  bitcoin    BTC  Bitcoin  01.05.2013        1  139.0  139.89  107.72
# 4  bitcoin    BTC  Bitcoin  02.05.2013        1    NaN  125.60     NaN
#
#     close  volume        market  close_ratio  spread
# 0  116.99     0.0  1.298955e+09       0.2882   32.17
# 1  144.54     0.0  1.603769e+09       0.7813   13.49
# 2  139.00     0.0  1.542813e+09       0.3843   12.88
# 3  116.99     0.0  1.298955e+09       0.2882   32.17
# 4  105.21     0.0  1.168517e+09       0.3881   33.32

# %% [markdown]
# ##### Задание 22. Визуализировать данные вашего скаченного DataSet в стиле Столбчатые диаграммы (подписать оси, заголовок)

# %%
x = myDF['date'].loc[(myDF['name'] == 'BUMO')]
y = myDF['open'].loc[(myDF['name'] == 'BUMO')]
plt.figure(figsize = (20,10))
plt.xticks(rotation =90, fontsize = 13)
plt.yticks(fontsize = 13)
plt.xlabel('Дата', fontsize = 15)
plt.ylabel('Цена', rotation = 0, fontsize = 15, loc = 'top')
plt.title('Диаграмма цен на входе криптовалюты "BUMO" с 14.09.2018 по 29.12.2013')
plt.bar(x,y)
# Out:
# <BarContainer object of 77 artists>

# %% [markdown]
# ##### Задание 23. Визуализировать данные вашего скаченного DataSet в стиле Точечный график (подписать оси, заголовок)

# %%
x = myDF['date'].loc[(myDF['name'] == 'BUMO')]
y = myDF['open'].loc[(myDF['name'] == 'BUMO')]
plt.figure(figsize = (20,10))
plt.xticks(rotation =90, fontsize = 13)
plt.yticks(fontsize = 13)
plt.grid(True)
plt.xlabel('Дата', fontsize = 15)
plt.ylabel('Цена', rotation = 0, fontsize = 15, loc = 'top')
plt.title('Диаграмма цен на входе криптовалюты "BUMO" с 14.09.2018 по 29.12.2013')
plt.scatter(x,y)

# %% [markdown]
# ##### Задание 24. Визуализировать данные вашего скаченного DataSet в стиле Столбчатые диаграммы (подписать оси, заголовок, столбцы зеленого цвета)

# %%
x = myDF['date'].loc[(myDF['name'] == 'BUMO')]
y = myDF['open'].loc[(myDF['name'] == 'BUMO')]
plt.figure(figsize = (20,10))
plt.xticks(rotation =90, fontsize = 13)
plt.yticks(fontsize = 13)
plt.xlabel('Дата', fontsize = 15)
plt.ylabel('Цена', rotation = 0, fontsize = 15, loc = 'top')
plt.title('Диаграмма цен на входе криптовалюты "BUMO" с 14.09.2018 по 29.12.2018')
plt.bar(x,y, color = "green")
# Out:
# <BarContainer object of 77 artists>

# %% [markdown]
# ##### Задание 25. Визуализировать изменённые данные вашего варианта в стиле Точечный график (подписать оси, заголовок, столбцы красного цвета)

# %%
x = myDF['date'].loc[(myDF['name'] == 'BUMO')]
y = myDF['open'].loc[(myDF['name'] == 'BUMO')]
plt.figure(figsize = (20,10))
plt.xticks(rotation =90, fontsize = 13)
plt.yticks(fontsize = 13)
plt.grid(True)
plt.xlabel('Дата', fontsize = 15)
plt.ylabel('Цена', rotation = 0, fontsize = 15, loc = 'top')
plt.title('Диаграмма цен на входе криптовалюты "BUMO" с 14.09.2018 по 29.12.2013')
plt.scatter(x,y, color = "red")

# %% [markdown]
# ##### Задание 26. Визуализировать данные вашего скаченного DataSet в стиле Линейный график (подписать оси, заголовок, цвет, стиль линии изменить на ваше усмотрение)

# %%
import numpy as np
x = myDF['date'].loc[(myDF['name'] == 'BUMO')]
y = myDF['open'].loc[(myDF['name'] == 'BUMO')]
plt.figure(figsize = (20,10), facecolor = "pink")
plt.xticks(rotation =90, fontsize = 13)
plt.yticks(np.arange(y.min(), y.max(), 0.005) , fontsize = 13)
plt.grid(True)
plt.xlabel('Дата', fontsize = 15)
plt.ylabel('Цена', rotation = 0, fontsize = 15, loc = 'top')
plt.title('Диаграмма цен на входе криптовалюты "BUMO" с 14.09.2018 по 29.12.2018')
plt.plot(x,y, color = "pink", linestyle = '-.', marker = 'o')

# %% [markdown]
# ##### Задание 27. Визуализировать данные вашего скаченного DataSet в стиле Цветовое распределение

# %%
x = myDF['open'].loc[(myDF['name'] == 'BUMO')]
y = myDF['close'].loc[(myDF['name'] == 'BUMO')]
z = myDF['high'].loc[(myDF['name'] == 'BUMO')]
c = myDF['low'].loc[(myDF['name'] == 'BUMO')]
plt.pcolor([x,y, z , c])
